# %%
from sympy import *
from sympy.plotting import plot

# %%
init_printing(use_unicode=False, wrap_line=False, no_global=True)

# %%
x = Symbol('x')

# %%
f = 3*x**2 + 3*x - 6
f
# Out:
#    2
# 3*x  + 3*x - 6

# %%
f.subs(x, 1/2)
# Out:
# -3.75000000000000

# %%
f.subs(x, 7)
# Out:
# 162

# %%
plot(f)
