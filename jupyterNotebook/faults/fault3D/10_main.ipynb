# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(16, 16))
ax = fig.add_subplot(111, projection='3d')

x = 0
y = 0
z = 0

ax.scatter(x, y, z, c='r', marker='o')
ax.scatter(0, 0, 3, c='y', marker='o')
ax.scatter(1, 0, 3, c='y', marker='o')
ax.scatter(2, 0, 3, c='y', marker='o')
ax.scatter(3, 0, 3, c='y', marker='o')
ax.scatter(4, 0, 2, c='r', marker='o')
ax.scatter(5, 0, 1, c='r', marker='o')
ax.scatter(6, 0, 0, c='g', marker='o')
ax.scatter(7, 0, 0, c='g', marker='o')
ax.scatter(8, 0, 0, c='g', marker='o')
ax.scatter(9, 0, 0, c='g', marker='o')
ax.scatter(0, 3, 3, c='b', marker='o')

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()
