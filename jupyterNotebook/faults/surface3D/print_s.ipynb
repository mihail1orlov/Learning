# %%
from lib.Point3d import Point3d
from lib.PointInfoPrinter import PointInfoPrinter

from lib.Plane import Plane
from lib.PlaneAnalyzer import PlaneAnalyzer
from lib.PlaneCreator import PlaneCreator

from lib.Plotter3d import Plotter3d

from lib.SurfacePlotter import SurfacePlotter
from lib.SurfaceIO import SurfaceIO
from lib.SurfaceManager import SurfaceManager

plotter = Plotter3d()

surface = SurfaceIO.load_from_file('data/FaultOperationsTests/inputSurface.json')

#surface = SurfaceIO.load_from_file('data/FaultOperationsTests/expectedShiftedGrid.json')
#surface = SurfaceIO.load_from_file('data/surface.json')
plotter.plot_surface(surface)

plane = PlaneCreator.from_points(Point3d(1200, 300, 1, 'y'), Point3d(1200, 300, 0, 'm'), Point3d(1100, 300, 1, 'k'))
#plane = Plane(0, 100, 0, 30000)
PlaneAnalyzer.print_info(plane)
#plotter.plot_plane(plane)

#points = SurfaceManager.generate_points_from_surface(surface)
points = SurfaceManager.process_surface(surface, plane)
plotter.plot_points(points)

plotter.show_plot()

surfacePlotter = SurfacePlotter()
surfacePlotter.plot_surface(surface, 'FaultOperationsTests')
surface2 = SurfaceIO.load_from_file('data/FaultOperationsTests/expectedShiftedGrid.json')
surfacePlotter.plot_surfaces(surface, surface2, 'input', 'output')

PointInfoPrinter.print_points(points)
PointInfoPrinter.print_summary(points)
# Out:
# Plane equation: 0x + 100y + 0z + -30000 = 0; Slope angle: 90.0 degrees
# index=1 (x=1000.0, y=100.0, z=0.3592499572674307, color=b)
# index=2 (x=1100.0, y=100.0, z=0.5941788606447406, color=b)
# index=3 (x=1200.0, y=100.0, z=0.25628071084716764, color=b)
# index=4 (x=1300.0, y=100.0, z=0.3000152188254762, color=b)
# index=5 (x=1400.0, y=100.0, z=0.6991079634392992, color=b)
# index=6 (x=1500.0, y=100.0, z=0.6744732582982389, color=b)
# index=7 (x=1000.0, y=200.0, z=0.1410292956840482, color=b)
# index=8 (x=1100.0, y=200.0, z=0.3081333116398335, color=b)
# index=9 (x=1200.0, y=200.0, z=0.5602852163688853, color=b)
# index=10 (x=1300.0, y=200.0, z=0.3034921608253808, color=b)
# index=11 (x=1400.0, y=200.0, z=0.9454578436502653, color=b)
# index=12 (x=1500.0, y=200.0, z=0.9072053609053274, color=b)
# index=13 (x=1000.0, y=300.0, z=0.19798772452767488, color=y)
# index=14 (x=1100.0, y=300.0, z=0.2703984666337115, color=y)
# index=15 (x=1200.0, y=300.0, z=0.28632213287122643, color=y)
# index=16 (x=1300.0, y=300.0, z=0.4983052619335848, color=y)
# index=17 (x=1400.0, y=300.0, z=0.7094316460427595, color=y)
# index=18 (x=1500.0, y=300.0, z=0.5811921554712238, color=y)
# index=19 (x=1000.0, y=400.0, z=0.7003286614151629, color=r)
# index=20 (x=1100.0, y=400.0, z=0.2923066431272803, color=r)
# index=21 (x=1200.0, y=400.0, z=0.09172118384593386, color=r)
# index=22 (x=1300.0, y=400.0, z=0.04953026391528126, color=r)
# index=23 (x=1400.0, y=400.0, z=0.164148665883724, color=r)
# index=24 (x=1500.0, y=400.0, z=0.8448100181855426, color=r)
# index=25 (x=1000.0, y=500.0, z=0.1271677480287382, color=r)
# index=26 (x=1100.0, y=500.0, z=0.8249295733598274, color=r)
# index=27 (x=1200.0, y=500.0, z=0.5144028252115113, color=r)
# index=28 (x=1300.0, y=500.0, z=0.01689434387801403, color=r)
# index=29 (x=1400.0, y=500.0, z=0.09850159332409325, color=r)
# index=30 (x=1500.0, y=500.0, z=0.6934748120054963, color=r)
# Summary:
# Total Points: 30
# Average x-coordinate: 1250.00
# Average y-coordinate: 300.00
# Average z-coordinate: 0.43
