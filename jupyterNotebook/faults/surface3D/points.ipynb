# %%
from lib.PointInfoPrinter import PointInfoPrinter
from lib.Plane import Plane
from lib.Point3d import Point3d
from lib.PlaneAnalyzer import PlaneAnalyzer
from lib.Plotter3d import Plotter3d
from lib.SurfaceIO import SurfaceIO
from lib.SurfaceManager import SurfaceManager

plotter = Plotter3d()

points = [
    Point3d(1200, 300, 1, 'y'),
    Point3d(1200, 300, 0, 'm'),
    Point3d(1100, 300, 1, 'k'),
]

points = [
    Point3d(1200, 300, 0.2, 'y'),
    Point3d(1200, 300, 0.7, 'm'),
    Point3d(1100, 300, 0.2, 'k'),
    
    Point3d(1000, 100, 0, 'b'),
    Point3d(1100, 100, 0, 'b'),
    Point3d(1200, 100, 0, 'b'),
    Point3d(1300, 100, 0, 'b'),
    Point3d(1400, 100, 0, 'b'),
    Point3d(1500, 100, 0, 'b'),
    Point3d(1000, 200, 0, 'b'),
    Point3d(1100, 200, 0, 'b'),
    Point3d(1200, 200, 0, 'b'),
    Point3d(1300, 200, 0, 'b'),
    Point3d(1400, 200, 0, 'b'),
    Point3d(1500, 200, 0, 'b'),
    Point3d(1000, 300, 1, 'r'),
    Point3d(1100, 300, 1, 'r'),
    Point3d(1200, 300, 1, 'r'),
    Point3d(1300, 300, 1, 'r'),
    Point3d(1400, 300, 1, 'r'),
    Point3d(1500, 300, 1, 'r'),
    Point3d(1000, 400, 1, 'r'),
    Point3d(1100, 400, 1, 'r'),
    Point3d(1200, 400, 1, 'r'),
    Point3d(1300, 400, 1, 'r'),
    Point3d(1400, 400, 1, 'r'),
    Point3d(1500, 400, 1, 'r'),
    Point3d(1000, 500, 1, 'r'),
    Point3d(1100, 500, 1, 'r'),
    Point3d(1200, 500, 1, 'r'),
    Point3d(1300, 500, 1, 'r'),
    Point3d(1400, 500, 1, 'r'),
    Point3d(1500, 500, 1, 'r'),
]
plotter.plot_points(points)

plotter.show_plot()




#surface = SurfaceIO.load_from_file('data/FaultOperationsTests/expectedShiftedGrid.json')
surface = SurfaceIO.load_from_file('data/surface_.json')
#plotter.plot_surface(surface)

#plane = Plane(1, 0, 0, 500)
plane = Plane(0, 100, 0, 30000)
PlaneAnalyzer.print_info(plane)
#plotter.plot_plane(plane)

#points = SurfaceManager.generate_points_from_surface(surface)
points = SurfaceManager.process_surface(surface, plane)
plotter.plot_points(points)

plotter.show_plot()

PointInfoPrinter.print_points(points)
PointInfoPrinter.print_summary(points)
# Out:
# Plane equation: 0x + 100y + 0z + 30000 = 0; Slope angle: 90.0 degrees
# index=1 (x=1000.0, y=100.0, z=0.1271677480287382, color=r)
# index=2 (x=1100.0, y=100.0, z=0.7003286614151629, color=r)
# index=3 (x=1200.0, y=100.0, z=0.19798772452767488, color=r)
# index=4 (x=1300.0, y=100.0, z=0.1410292956840482, color=r)
# index=5 (x=1400.0, y=100.0, z=0.3592499572674307, color=r)
# index=6 (x=1500.0, y=100.0, z=0.8249295733598274, color=r)
# index=7 (x=1000.0, y=200.0, z=0.2923066431272803, color=r)
# index=8 (x=1100.0, y=200.0, z=0.2703984666337115, color=r)
# index=9 (x=1200.0, y=200.0, z=0.3081333116398335, color=r)
# index=10 (x=1300.0, y=200.0, z=0.5941788606447406, color=r)
# index=11 (x=1400.0, y=200.0, z=0.5144028252115113, color=r)
# index=12 (x=1500.0, y=200.0, z=0.09172118384593386, color=r)
# index=13 (x=1000.0, y=300.0, z=0.28632213287122643, color=r)
# index=14 (x=1100.0, y=300.0, z=0.5602852163688853, color=r)
# index=15 (x=1200.0, y=300.0, z=0.25628071084716764, color=r)
# ...
