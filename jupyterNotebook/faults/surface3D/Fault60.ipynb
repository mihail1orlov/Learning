# %%
from lib.Point3d import Point3d
from lib.PointInfoPrinter import PointInfoPrinter

from lib.Plane import Plane
from lib.PlaneAnalyzer import PlaneAnalyzer
from lib.PlaneCreator import PlaneCreator

from lib.Plotter3d import Plotter3d

from lib.SurfacePlotter import SurfacePlotter
from lib.SurfaceIO import SurfaceIO
from lib.SurfaceManager import SurfaceManager

init_points = [Point3d(1200.5773502692, 100, 2, 'y'), Point3d(1200, 300, 0, 'k'), Point3d(1200, 100, 0, 'm')]
input = 'data/FaultOperationsTests/fault-60-input.json'
output = 'data/FaultOperationsTests/fault-60-output.json'


plotter_points = Plotter3d()
PointInfoPrinter.print_points(init_points)
plotter_points.plot_points(init_points)
plotter_points.show_plot('input points')

plotter_input = Plotter3d()
surface_input = SurfaceIO.load_from_file(input)
plotter_input.plot_surface(surface_input)
plane = PlaneCreator.from_points(init_points[0], init_points[1], init_points[2])
PlaneAnalyzer.print_info(plane)
points_input = SurfaceManager.process_surface(surface_input, plane)
plotter_input.plot_points(points_input)
plotter_input.show_plot('input')
PointInfoPrinter.print_points(points_input)

plotter_output = Plotter3d()
surface_output = SurfaceIO.load_from_file(output)
points_output = SurfaceManager.process_surface(surface_output, plane)
plotter_output.plot_points(points_output)
plotter_output.plot_surface(surface_output)
plotter_output.show_plot('output')

surfacePlotter = SurfacePlotter()
surfacePlotter.plot_surfaces(surface_input, surface_output, 'input', 'output')

PointInfoPrinter.print_points(points_output)
PointInfoPrinter.print_summary(points_output)
# Out:
# index=1 (x=1200.5773502692, y=100, z=2, color=y)
# index=2 (x=1200, y=300, z=0, color=k)
# index=3 (x=1200, y=100, z=0, color=m)
# Plane equation: -400.0x + 0.0y + 115.47005383999931z + 480000.0 = 0; Slope angle: 73.89788624773973 degrees
# index=1 (x=1000.0, y=100.0, z=0.0, color=r)
# index=2 (x=1100.0, y=100.0, z=-400.0, color=b)
# index=3 (x=1200.0, y=100.0, z=-0.05, color=b)
# index=4 (x=1300.0, y=100.0, z=200.0, color=b)
# index=5 (x=1400.0, y=100.0, z=200.0, color=b)
# index=6 (x=1500.0, y=100.0, z=200.0, color=b)
# index=7 (x=1000.0, y=200.0, z=0.0, color=r)
# index=8 (x=1100.0, y=200.0, z=0.0, color=r)
# index=9 (x=1200.0, y=200.0, z=0.05, color=r)
# index=10 (x=1300.0, y=200.0, z=400.0, color=r)
# index=11 (x=1400.0, y=200.0, z=200.0, color=b)
# index=12 (x=1500.0, y=200.0, z=200.0, color=b)
# index=13 (x=1000.0, y=300.0, z=0.0, color=r)
# index=14 (x=1100.0, y=300.0, z=0.0, color=r)
# index=15 (x=1200.0, y=300.0, z=0.0, color=y)
# index=16 (x=1300.0, y=300.0, z=0.0, color=b)
# index=17 (x=1400.0, y=300.0, z=0.0, color=b)
# index=18 (x=1500.0, y=300.0, z=0.0, color=b)
# index=19 (x=1000.0, y=400.0, z=0.0, color=r)
# index=20 (x=1100.0, y=400.0, z=0.0, color=r)
# index=21 (x=1200.0, y=400.0, z=0.0, color=y)
# index=22 (x=1300.0, y=400.0, z=0.0, color=b)
# index=23 (x=1400.0, y=400.0, z=0.0, color=b)
# index=24 (x=1500.0, y=400.0, z=0.0, color=b)
# index=25 (x=1000.0, y=500.0, z=0.0, color=r)
# index=26 (x=1100.0, y=500.0, z=0.0, color=r)
# index=27 (x=1200.0, y=500.0, z=0.0, color=y)
# index=28 (x=1300.0, y=500.0, z=0.0, color=b)
# index=29 (x=1400.0, y=500.0, z=0.0, color=b)
# index=30 (x=1500.0, y=500.0, z=0.0, color=b)
# index=1 (x=1000.0, y=100.0, z=0.0, color=r)
# index=2 (x=1100.0, y=100.0, z=-400.0, color=b)
# index=3 (x=1200.0, y=100.0, z=-400.0, color=b)
# index=4 (x=1300.0, y=100.0, z=-400.0, color=b)
# index=5 (x=1400.0, y=100.0, z=-400.0, color=b)
# index=6 (x=1500.0, y=100.0, z=-400.0, color=b)
# index=7 (x=1000.0, y=200.0, z=0.0, color=r)
# index=8 (x=1100.0, y=200.0, z=0.0, color=r)
# index=9 (x=1200.0, y=200.0, z=0.05, color=r)
# index=10 (x=1300.0, y=200.0, z=400.0, color=r)
# index=11 (x=1400.0, y=200.0, z=-400.0, color=b)
# index=12 (x=1500.0, y=200.0, z=-400.0, color=b)
# index=13 (x=1000.0, y=300.0, z=0.0, color=r)
# index=14 (x=1100.0, y=300.0, z=0.0, color=r)
# index=15 (x=1200.0, y=300.0, z=0.0, color=y)
# index=16 (x=1300.0, y=300.0, z=-400.0, color=b)
# index=17 (x=1400.0, y=300.0, z=-400.0, color=b)
# index=18 (x=1500.0, y=300.0, z=-400.0, color=b)
# index=19 (x=1000.0, y=400.0, z=0.0, color=r)
# index=20 (x=1100.0, y=400.0, z=0.0, color=r)
# index=21 (x=1200.0, y=400.0, z=0.0, color=y)
# index=22 (x=1300.0, y=400.0, z=-400.0, color=b)
# index=23 (x=1400.0, y=400.0, z=-400.0, color=b)
# index=24 (x=1500.0, y=400.0, z=-400.0, color=b)
# index=25 (x=1000.0, y=500.0, z=0.0, color=r)
# index=26 (x=1100.0, y=500.0, z=0.0, color=r)
# index=27 (x=1200.0, y=500.0, z=0.0, color=y)
# index=28 (x=1300.0, y=500.0, z=-400.0, color=b)
# index=29 (x=1400.0, y=500.0, z=-400.0, color=b)
# index=30 (x=1500.0, y=500.0, z=-400.0, color=b)
# Summary:
# Total Points: 30
# Average x-coordinate: 1250.00
# Average y-coordinate: 300.00
# Average z-coordinate: -200.00
