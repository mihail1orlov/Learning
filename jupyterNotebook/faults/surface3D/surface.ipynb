# %%
from lib.PointInfoPrinter import PointInfoPrinter
from lib.Plotter3d import Plotter3d
from lib.Surface import Surface
from lib.SurfaceIO import SurfaceIO
from lib.SurfaceManager import SurfaceManager

p = Plotter3d()
s = SurfaceIO.load_from_file('data/FaultOperationsTests/inputSurface.json')
p.plot_surface(s)
p.show_plot()
p_ = SurfaceManager.generate_points_from_surface(s)
PointInfoPrinter.print_points(p_)

#surface = SurfaceManager.create_surface_with_random_values(minEast=1000, minNorth=100, maxEast=1500, maxNorth=500, numRows=5, numCols=6)
#SurfaceIO.save_to_file(surface, 'data/surface.json')
surface = SurfaceIO.load_from_file('data/FaultOperationsTests/expectedShiftedGrid.json')
points = SurfaceManager.generate_points_from_surface(surface)



plotter = Plotter3d()
plotter.plot_surface(surface)
plotter.plot_points(points)
plotter.show_plot()

#PointInfoPrinter.print_points(points)
#PointInfoPrinter.print_summary(points)
# Out:
# index=1 (x=1000.0, y=100.0, z=0.3592499572674307, color=r)
# index=2 (x=1100.0, y=100.0, z=0.5941788606447406, color=r)
# index=3 (x=1200.0, y=100.0, z=0.25628071084716764, color=r)
# index=4 (x=1300.0, y=100.0, z=0.3000152188254762, color=r)
# index=5 (x=1400.0, y=100.0, z=0.6991079634392992, color=r)
# index=6 (x=1500.0, y=100.0, z=0.6744732582982389, color=r)
# index=7 (x=1000.0, y=200.0, z=0.1410292956840482, color=r)
# index=8 (x=1100.0, y=200.0, z=0.3081333116398335, color=r)
# index=9 (x=1200.0, y=200.0, z=0.5602852163688853, color=r)
# index=10 (x=1300.0, y=200.0, z=0.3034921608253808, color=r)
# index=11 (x=1400.0, y=200.0, z=0.9454578436502653, color=r)
# index=12 (x=1500.0, y=200.0, z=0.9072053609053274, color=r)
# index=13 (x=1000.0, y=300.0, z=0.19798772452767488, color=r)
# index=14 (x=1100.0, y=300.0, z=0.2703984666337115, color=r)
# index=15 (x=1200.0, y=300.0, z=0.28632213287122643, color=r)
# index=16 (x=1300.0, y=300.0, z=0.4983052619335848, color=r)
# index=17 (x=1400.0, y=300.0, z=0.7094316460427595, color=r)
# index=18 (x=1500.0, y=300.0, z=0.5811921554712238, color=r)
# index=19 (x=1000.0, y=400.0, z=0.7003286614151629, color=r)
# index=20 (x=1100.0, y=400.0, z=0.2923066431272803, color=r)
# index=21 (x=1200.0, y=400.0, z=0.09172118384593386, color=r)
# index=22 (x=1300.0, y=400.0, z=0.04953026391528126, color=r)
# index=23 (x=1400.0, y=400.0, z=0.164148665883724, color=r)
# index=24 (x=1500.0, y=400.0, z=0.8448100181855426, color=r)
# index=25 (x=1000.0, y=500.0, z=0.1271677480287382, color=r)
# index=26 (x=1100.0, y=500.0, z=0.8249295733598274, color=r)
# index=27 (x=1200.0, y=500.0, z=0.5144028252115113, color=r)
# index=28 (x=1300.0, y=500.0, z=0.01689434387801403, color=r)
# index=29 (x=1400.0, y=500.0, z=0.09850159332409325, color=r)
# index=30 (x=1500.0, y=500.0, z=0.6934748120054963, color=r)
