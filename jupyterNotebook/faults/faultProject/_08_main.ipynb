# %%
import matplotlib.pyplot as plt
import numpy as np
from geometry import Line, Point2D
from visualization import visualize

def define_points():
    points = [
        #Point2D(9999.000000001313, 10199.8134765625),
        #Point2D(10002.000000001324, 7486.134356717739),
        Point2D(5, 5, color='y', name='yy'),
        Point2D(25, 10, color='c', name='cc'),
        Point2D(30, 30, color='r', name='rr'),
        Point2D(10, 25, color='m', name='mm'),
        Point2D(20, 15, color='g', name='gg'),
        #Point2D(7000, 9500, color='y', name='y_false'),
        #Point2D(10000, 8500, color='m', name='m_true'),
        #Point2D(10002.000000001324, 10199.5546875)
    ]
    return points    

# Initialize the line
points = define_points()

#line = Line.from_angle_point(85, points[0])
line_g = Line.from_two_points(points[1], points[0])
line_g.name = 'green'
line_g.color = 'g'

line_r = Line.from_two_points(points[1], points[2])
line_r.name = 'red'
line_r.color = 'r'

line_m = Line.from_two_points(points[3], points[2])
line_m.name = 'm'
line_m.color = 'm'

line_b = Line.from_angle_point(10, points[4])
#line_b = Line.from_two_points(points[0], points[4])
line_b.name = 'blue'
line_b.color = 'b'

#line_y = Line.from_angle_point(33.690067525979785, points[3])
line_y = Line.from_two_points(points[0], points[3])
line_y.name = 'yellow'
line_y.color = 'y'

intersection = line_b.intersection(line_r)
if intersection != None:
    intersection.name = 'b'
    intersection.color = 'k'
    points.append(intersection)

line_k = Line.from_two_points(points[5], points[4])
#line_k = Line.from_angle_point(0, points[4])
line_k.name = 'black'
line_k.color = 'k'

visualize(points, [line_k, line_b, line_r, line_g, line_y, line_m], show_legend=False)
# Out:
# Line black details: A = 1.1528638812657626, B = -6.53821597031644, C = -75.01596192943134
# Angle of inclination: 9.999999999999984 degrees
# Line: black, point:yy - isPositive: True
# Line: black, point:cc - isPositive: True
# Line: black, point:rr - isPositive: False
# Line: black, point:mm - isPositive: False
# Line: black, point:gg - isPositive: True
# Line: black, point:b - isPositive: True
#
#
# Line blue details: A = 0.17632698070846498, B = -1, C = -11.4734603858307
# Angle of inclination: 10.0 degrees
# Line: blue, point:yy - isPositive: True
# Line: blue, point:cc - isPositive: True
# Line: blue, point:rr - isPositive: False
# Line: blue, point:mm - isPositive: False
# Line: blue, point:gg - isPositive: True
# Line: blue, point:b - isPositive: True
#
#
# Line red details: A = -20, B = 5, C = -450
# Angle of inclination: 75.96375653207353 degrees
# Line: red, point:yy - isPositive: True
# Line: red, point:cc - isPositive: True
# Line: red, point:rr - isPositive: True
# Line: red, point:mm - isPositive: True
# Line: red, point:gg - isPositive: True
# Line: red, point:b - isPositive: True
#
#
# Line green details: A = 5, B = -20, C = -75
# Angle of inclination: 14.036243467926479 degrees
# Line: green, point:yy - isPositive: True
# Line: green, point:cc - isPositive: True
# Line: green, point:rr - isPositive: False
# Line: green, point:mm - isPositive: False
# Line: green, point:gg - isPositive: False
# Line: green, point:b - isPositive: False
#
#
# Line yellow details: A = -20, B = 5, C = -75
# Angle of inclination: 75.96375653207353 degrees
# Line: yellow, point:yy - isPositive: True
# Line: yellow, point:cc - isPositive: False
# Line: yellow, point:rr - isPositive: False
# Line: yellow, point:mm - isPositive: True
# Line: yellow, point:gg - isPositive: False
# Line: yellow, point:b - isPositive: False
#
#
# Line m details: A = -5, B = 20, C = 450
# Angle of inclination: 14.036243467926479 degrees
# Line: m, point:yy - isPositive: False
# Line: m, point:cc - isPositive: False
# Line: m, point:rr - isPositive: True
# Line: m, point:mm - isPositive: True
# Line: m, point:gg - isPositive: False
# Line: m, point:b - isPositive: False
#
# Checking for equal lines:
