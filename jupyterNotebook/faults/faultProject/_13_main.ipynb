# %%
import matplotlib.pyplot as plt
import numpy as np
from geometry import Line, Point2D
from visualization import visualize
'''
Name: Flat_4. Md: 10519.945708618448, Tvd: 8385.646484375
valid # of grids = 54372
valid # of grids = 51420
Name: Flat_5. Md: 10577.271403217654, Tvd: 8484.9375
'''
def define_points():
    points = [# throw = 100 da = 60
        Point2D(10050, 7489.43017578125, color='y', name='Flat_3'),
        Point2D(10410, 7984.300292968751, color='c', name='Flat_1'),
        Point2D(10690, 8402.190429687502, color='r', name='Flat_2'),
        Point2D(10771, 8485.646484375, color='m', name='Flat_4'),
        Point2D(10826, 8584.9375, color='g', name='Flat_5'),
        
        Point2D(9945.473886157337, 7389.43017578125, color='y', name='i_0'),
        Point2D(10231.187281529441, 7884.300292968751, color='c', name='i_1'),
        Point2D(10472.4562644557, 8302.190429687502, color='r', name='i_2'),
        Point2D(10520.639640095033, 8385.646484375, color='m', name='i_3'),
        Point2D(10577.965334694238, 8484.9375, color='g', name='i_4'),
        
        Point2D(10000.000000001317, 7343.730913905285, color='g', name='start'),
    ]
    return points    

# Initialize the line
points = define_points()

line_y = Line.from_angle_point(0, points[0])
#line_y = Line.from_two_points(points[0], points[1])
line_y.name = 'yellow'
line_y.color = 'y'

line_b = Line.from_angle_point(0, points[1])
#line_b = Line.from_two_points(points[0], points[4])
line_b.name = 'blue'
line_b.color = 'b'

line_m = Line.from_angle_point(0, points[2])
#line_m = Line.from_two_points(points[1], points[0])
line_m.name = 'm'
line_m.color = 'm'

line_g = Line.from_angle_point(0, points[3])
#line_g = Line.from_two_points(points[1], points[0])
line_g.name = 'green'
line_g.color = 'g'

line_r = Line.from_angle_point(0, points[4])
#line_r = Line.from_two_points(points[1], points[0])
line_r.name = 'red'
line_r.color = 'r'

intersection = line_b.intersection(line_r)
if intersection != None:
    intersection.name = 'b'
    intersection.color = 'k'
    points.append(intersection)

line_k = Line.from_two_points(points[4], points[0])
#line_k = Line.from_angle_point(0, points[4])
line_k.name = 'black'
line_k.color = 'k'

#line_y = Line.from_angle_point(0, points[0])
line_y = Line.from_two_points(points[5], points[9])
line_y.name = 'yellow'
line_y.color = 'y'

visualize(points, [line_y, line_b, line_m, line_g, line_r, line_k], show_legend=False)
# Out:
# Line yellow details: A = -1095.50732421875, B = 632.4914485369009, C = -6221588.089369509
# Angle of inclination: 60.00000000000005 degrees
# Line: yellow, point:Flat_3 - isPositive: False
# Line: yellow, point:Flat_1 - isPositive: False
# Line: yellow, point:Flat_2 - isPositive: False
# Line: yellow, point:Flat_4 - isPositive: False
# Line: yellow, point:Flat_5 - isPositive: False
# Line: yellow, point:i_0 - isPositive: True
# Line: yellow, point:i_1 - isPositive: True
# Line: yellow, point:i_2 - isPositive: True
# Line: yellow, point:i_3 - isPositive: True
# Line: yellow, point:i_4 - isPositive: True
# Line: yellow, point:start - isPositive: False
#
#
# Line blue details: A = 0.0, B = -1, C = -7984.300292968751
# Angle of inclination: 0.0 degrees
# Line: blue, point:Flat_3 - isPositive: True
# Line: blue, point:Flat_1 - isPositive: True
# Line: blue, point:Flat_2 - isPositive: False
# Line: blue, point:Flat_4 - isPositive: False
# Line: blue, point:Flat_5 - isPositive: False
# Line: blue, point:i_0 - isPositive: True
# Line: blue, point:i_1 - isPositive: True
# Line: blue, point:i_2 - isPositive: False
# Line: blue, point:i_3 - isPositive: False
# Line: blue, point:i_4 - isPositive: False
# Line: blue, point:start - isPositive: True
#
#
# Line m details: A = 0.0, B = -1, C = -8402.190429687502
# Angle of inclination: 0.0 degrees
# Line: m, point:Flat_3 - isPositive: True
# Line: m, point:Flat_1 - isPositive: True
# Line: m, point:Flat_2 - isPositive: True
# Line: m, point:Flat_4 - isPositive: False
# Line: m, point:Flat_5 - isPositive: False
# Line: m, point:i_0 - isPositive: True
# Line: m, point:i_1 - isPositive: True
# Line: m, point:i_2 - isPositive: True
# Line: m, point:i_3 - isPositive: True
# Line: m, point:i_4 - isPositive: False
# Line: m, point:start - isPositive: True
#
#
# Line green details: A = 0.0, B = -1, C = -8485.646484375
# Angle of inclination: 0.0 degrees
# Line: green, point:Flat_3 - isPositive: True
# Line: green, point:Flat_1 - isPositive: True
# Line: green, point:Flat_2 - isPositive: True
# Line: green, point:Flat_4 - isPositive: True
# Line: green, point:Flat_5 - isPositive: False
# Line: green, point:i_0 - isPositive: True
# Line: green, point:i_1 - isPositive: True
# Line: green, point:i_2 - isPositive: True
# Line: green, point:i_3 - isPositive: True
# Line: green, point:i_4 - isPositive: True
# Line: green, point:start - isPositive: True
#
#
# Line red details: A = 0.0, B = -1, C = -8584.9375
# Angle of inclination: 0.0 degrees
# Line: red, point:Flat_3 - isPositive: True
# Line: red, point:Flat_1 - isPositive: True
# Line: red, point:Flat_2 - isPositive: True
# Line: red, point:Flat_4 - isPositive: True
# Line: red, point:Flat_5 - isPositive: True
# Line: red, point:i_0 - isPositive: True
# Line: red, point:i_1 - isPositive: True
# Line: red, point:i_2 - isPositive: True
# Line: red, point:i_3 - isPositive: True
# Line: red, point:i_4 - isPositive: True
# Line: red, point:start - isPositive: True
#
#
# Line black details: A = 1095.50732421875, B = -776, C = 5198050.7919921875
# Angle of inclination: 54.68824168654467 degrees
# Line: black, point:Flat_3 - isPositive: True
# Line: black, point:Flat_1 - isPositive: True
# Line: black, point:Flat_2 - isPositive: False
# Line: black, point:Flat_4 - isPositive: True
# Line: black, point:Flat_5 - isPositive: True
# Line: black, point:i_0 - isPositive: False
# Line: black, point:i_1 - isPositive: False
# Line: black, point:i_2 - isPositive: False
# Line: black, point:i_3 - isPositive: False
# Line: black, point:i_4 - isPositive: False
# Line: black, point:start - isPositive: True
#
# Checking for equal lines:
