# %%
import matplotlib.pyplot as plt
import numpy as np
from geometry import Line, Point2D
from visualization import visualize
#,\"Tvd\":
def define_points():
    points = [# throw = -100 da = -91
        Point2D(9999.3, 7389.4, color='m', name='intersection_1'),
        Point2D(10007.9, 7884.3, color='g', name='intersection_2'),
        Point2D(10015.2, 8302.1, color='g', name='intersection_3'),
        Point2D(10016.7, 8385.6, color='g', name='intersection_5'),
        Point2D(10018.4, 8484.9, color='g', name='intersection_4'),
        #Point2D(10051.00000000172, 7490.604226105885, color='g', name='gg'),
    ]
    return points    

# Initialize the line
points = define_points()

line_y = Line.from_angle_point(0, points[0])
#line_y = Line.from_two_points(points[0], points[1])
line_y.name = 'yellow'
line_y.color = 'y'

line_b = Line.from_angle_point(0, points[1])
#line_b = Line.from_two_points(points[0], points[4])
line_b.name = 'blue'
line_b.color = 'b'

line_m = Line.from_angle_point(0, points[2])
#line_m = Line.from_two_points(points[1], points[0])
line_m.name = 'm'
line_m.color = 'm'

line_g = Line.from_angle_point(0, points[3])
#line_g = Line.from_two_points(points[1], points[0])
line_g.name = 'green'
line_g.color = 'g'

line_r = Line.from_angle_point(0, points[4])
#line_r = Line.from_two_points(points[1], points[0])
line_r.name = 'red'
line_r.color = 'r'

intersection = line_b.intersection(line_r)
if intersection != None:
    intersection.name = 'b'
    intersection.color = 'k'
    points.append(intersection)

line_k = Line.from_two_points(points[4], points[0])
#line_k = Line.from_angle_point(0, points[4])
line_k.name = 'black'
line_k.color = 'k'

visualize(points, [line_y, line_b, line_m, line_g, line_r, line_k], show_legend=False)
# Out:
# Line yellow details: A = 0.0, B = -1, C = -7389.4
# Angle of inclination: 0.0 degrees
# Line: yellow, point:intersection_1 - isPositive: True
# Line: yellow, point:intersection_2 - isPositive: False
# Line: yellow, point:intersection_3 - isPositive: False
# Line: yellow, point:intersection_5 - isPositive: False
# Line: yellow, point:intersection_4 - isPositive: False
#
#
# Line blue details: A = 0.0, B = -1, C = -7884.3
# Angle of inclination: 0.0 degrees
# Line: blue, point:intersection_1 - isPositive: True
# Line: blue, point:intersection_2 - isPositive: True
# Line: blue, point:intersection_3 - isPositive: False
# Line: blue, point:intersection_5 - isPositive: False
# Line: blue, point:intersection_4 - isPositive: False
#
#
# Line m details: A = 0.0, B = -1, C = -8302.1
# Angle of inclination: 0.0 degrees
# Line: m, point:intersection_1 - isPositive: True
# Line: m, point:intersection_2 - isPositive: True
# Line: m, point:intersection_3 - isPositive: True
# Line: m, point:intersection_5 - isPositive: False
# Line: m, point:intersection_4 - isPositive: False
#
#
# Line green details: A = 0.0, B = -1, C = -8385.6
# Angle of inclination: 0.0 degrees
# Line: green, point:intersection_1 - isPositive: True
# Line: green, point:intersection_2 - isPositive: True
# Line: green, point:intersection_3 - isPositive: True
# Line: green, point:intersection_5 - isPositive: True
# Line: green, point:intersection_4 - isPositive: False
#
#
# Line red details: A = 0.0, B = -1, C = -8484.9
# Angle of inclination: 0.0 degrees
# Line: red, point:intersection_1 - isPositive: True
# Line: red, point:intersection_2 - isPositive: True
# Line: red, point:intersection_3 - isPositive: True
# Line: red, point:intersection_5 - isPositive: True
# Line: red, point:intersection_4 - isPositive: True
#
#
# Line black details: A = 1095.5, B = -19.100000000000364, C = 10813095.609999996
# Angle of inclination: 89.00115150806018 degrees
# Line: black, point:intersection_1 - isPositive: True
# Line: black, point:intersection_2 - isPositive: False
# Line: black, point:intersection_3 - isPositive: False
# Line: black, point:intersection_5 - isPositive: True
# Line: black, point:intersection_4 - isPositive: True
#
# Checking for equal lines:
